# %% [markdown]
# ### Introduction to Clustering
#
# **Clustering** is an **unsupervised learning** technique in machine learning used to group data points into clusters based on their similarities or patterns. Unlike supervised learning, clustering doesn’t require labeled data; the algorithm discovers the structure in the data on its own.
#
# ### Objectives of Clustering
# - **Group similar data points** together.
# - **Summarize data** by representing clusters.
# - **Discover hidden patterns** or structures in data.
# - Used in exploratory data analysis, recommendation systems, image segmentation, and more.
#
# ---
#
# ### Types of Clustering Algorithms
#
# 1. **Partition-Based Clustering**:
#    - Divides data into a predefined number of clusters.
#    - Example: **K-Means**.
#
# 2. **Hierarchical Clustering**:
#    - Builds a tree (dendrogram) structure.
#    - Example: Agglomerative clustering (bottom-up) or divisive clustering (top-down).
#
# 3. **Density-Based Clustering**:
#    - Groups dense regions of data points.
#    - Example: **DBSCAN** (Density-Based Spatial Clustering of Applications with Noise).
#
# 4. **Model-Based Clustering**:
#    - Assumes data is generated from a mixture of probability distributions.
#    - Example: Gaussian Mixture Models (GMM).
#
# 5. **Grid-Based Clustering**:
#    - Divides the data space into a finite number of cells and clusters them.
#    - Example: STING.
#
# ---
#
# ### Key Concepts in Clustering
#
# 1. **Centroid**: The center of a cluster.
# 2. **Intra-cluster Distance**: Measures how compact a cluster is.
# 3. **Inter-cluster Distance**: Measures how well-separated clusters are.
# 4. **Number of Clusters (k)**: Determining the optimal number of clusters is a common challenge.
#
# ---
#
# ### Example Algorithm: K-Means Clustering
#
# **K-Means** is one of the most popular clustering algorithms. It minimizes the sum of squared distances between points and their cluster centroids.
#
# #### Steps:
# 1. Choose the number of clusters (**k**).
# 2. Initialize **k centroids** randomly.
# 3. Assign each data point to the nearest centroid (forming clusters).
# 4. Update centroids by calculating the mean of all points in a cluster.
# 5. Repeat steps 3-4 until the centroids stabilize or a maximum number of iterations is reached.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Generate sample data
X, _ = make_blobs(n_samples=300, centers=4, random_state=42)

# Apply K-Means
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_  # Cluster assignments
centroids = kmeans.cluster_centers_

# Plot the results
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.title("K-Means Clustering")
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
X
# Out:
# array([[ -9.29768866,   6.47367855],
#        [ -9.69874112,   6.93896737],
#        [ -1.68665271,   7.79344248],
#        [ -7.09730839,  -5.78133274],
#        [-10.87645229,   6.3154366 ],
#        [ -6.02196757,  -7.04004812],
#        [  4.81305976,   2.35848706],
#        [ -6.46669574,  -7.44383415],
#        [ -2.98837186,   8.82862715],
#        [  3.44857534,   2.62972329],
#        [ -3.11090424,  10.86656431],
#        [  4.99689432,   1.28026009],
#        [ -2.30033403,   7.054616  ],
#        [ -3.92456837,   8.59364081],
#        [ -9.48897033,   6.83639753],
#        [ -3.21125072,   8.68662398],
#        [-10.46587019,   7.37160786],
#        [  2.61473625,   2.159624  ],
#        [ -2.41212007,   9.98293112],
#        [ -1.92234053,  11.20474175],
#        [  5.79847442,   1.15248737],
#        [ -2.67048333,   9.41833699],
#        [ -5.90450746,  -7.02716697],
#        [ -8.95065581,   7.10255332],
#        [ -2.97261532,   8.54855637],
# ...

# %% [markdown]
# The image shows the results of **K-Means Clustering** applied to a dataset. Key features of the plot are:
#
# 1. **Clusters**: Four distinct clusters are visible, each represented by a unique color (yellow, purple, teal, and blue).
# 2. **Centroids**: The cluster centroids are marked with large red "X" symbols. These represent the mean position of all points in their respective clusters.
# 3. **Cluster Separation**: The clusters are well-separated, indicating that the K-Means algorithm has successfully grouped the data based on proximity.
# 4. **Axes**: The plot spans values from approximately -10 to 7 on the x-axis and from -10 to 10 on the y-axis.
#
# This visualization helps to interpret how data points are grouped and the central position of each cluster.

# %% [markdown]
# ### Evaluating Clustering Performance
#
# 1. **Silhouette Score**:
#    - Measures how similar a point is to its cluster versus other clusters.
#    - Ranges from -1 (poor clustering) to +1 (good clustering).
#
# 2. **Inertia (Within-cluster Sum of Squares)**:
#    - Measures compactness. Lower inertia is better but may lead to overfitting.
#
# 3. **Elbow Method**:
#    - Plots inertia against the number of clusters to find the optimal **k**.

# %% [markdown]
#    ### Real-Life Applications of Clustering
#
# 1. **Customer Segmentation**:
#    - Group customers based on buying behavior for targeted marketing.
#
# 2. **Image Compression**:
#    - Use clustering to group similar pixel colors in an image.
#
# 3. **Document Clustering**:
#    - Cluster similar documents for organization or topic discovery.
#
# 4. **Anomaly Detection**:
#    - Outliers in clustering can indicate anomalies in the data.

# %% [markdown]
# ### Practical Example: Clustering Students Based on Test Scores
# Imagine you want to group students based on their test scores in Math and English.

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Example student scores: [Math, English]
scores = np.array([
    [85, 70], [78, 65], [92, 80], [50, 45], [49, 40], [45, 42],
    [90, 95], [88, 90], [55, 50], [60, 52], [62, 57]
])

# Apply K-Means (2 clusters)
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(scores)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Plot results
plt.scatter(scores[:, 0], scores[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.xlabel("Math Score")
plt.ylabel("English Score")
plt.title("Student Clustering")
plt.legend()
plt.show()

# %% [markdown]
# ### **Analysis of the Student Clustering Plot**
#
# #### **Overview**
# This plot represents the clustering of student performance based on two academic scores:
# 1. **Math Scores** (x-axis)
# 2. **English Scores** (y-axis)
#
# Clusters are visually grouped, and centroids (red "X") represent the center of each cluster.
#
# ---
#
# ### **Key Observations**
#
# 1. **Clusters**:
#    - The students are divided into **two clusters**:
#      - **Cluster 1 (Purple)**: Represents students with lower scores in both Math and English.
#      - **Cluster 2 (Yellow)**: Represents students with higher scores in both subjects.
#
# 2. **Centroids**:
#    - Each cluster is centered around a calculated centroid, shown as a red "X".
#    - The centroids are positioned based on the average Math and English scores of the students in their respective clusters.
#
# 3. **Performance Segmentation**:
#    - Students in the **purple cluster** likely require additional support, as their scores are clustered in the lower range.
#    - Students in the **yellow cluster** are high achievers, scoring consistently higher in both subjects.
#
# ---
#
# ### **Insights**
# 1. **Linear Relationship**:
#    - There seems to be a linear relationship between Math and English scores (students with higher Math scores tend to have higher English scores and vice versa).
#
# 2. **Cluster Boundaries**:
#    - There is a clear separation between the two clusters, suggesting that students fall distinctly into one of the two performance groups.
#
# ---
#
# ### **Potential Applications**
# - **Tailored Interventions**:
#   - Students in the lower-performing cluster can be targeted for extra tutoring or support.
# - **Performance Trends**:
#   - This clustering can help identify trends in student performance and possible correlations between subjects.
# - **Group Recommendations**:
#   - Programs or study plans can be designed for students in each cluster to maximize their academic growth.
